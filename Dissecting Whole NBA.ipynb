# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

# %%
NBA_Team_Stats = pd.read_csv('team_season_statlines.csv')
NBA_Team_Stats_copy = NBA_Team_Stats.copy()
NBA_Team_Stats_copy_df = pd.DataFrame(NBA_Team_Stats_copy)
NBA_Team_Stats_copy_df
# Out:
#     team  season  wins    fg   fga  fg_percent  three_point  three_point_att  \
# 0    ATL    2024    34  43.3  92.8       0.466         13.8             37.7
# 1    ATL    2023    41  44.6  92.4       0.483         10.8             30.5
# 2    ATL    2022    43  41.5  88.3       0.470         12.9             34.4
# 3    ATL    2021    41  40.8  87.2       0.468         12.4             33.4
# 4    ATL    2020    20  40.6  90.6       0.449         12.0             36.1
# ..   ...     ...   ...   ...   ...         ...          ...              ...
# 740  WAS    2004    25  33.6  80.0       0.421          5.3             15.5
# 741  WAS    2003    37  34.3  78.0       0.440          3.1              9.9
# 742  WAS    2002    37  35.8  81.3       0.441          3.7              9.6
# 743  WAS    2001    19  34.5  78.7       0.439          3.4             10.3
# 744  WAS    2000    29  36.7  81.5       0.451          4.1             10.9
#
# ...

# %%
NBA_Team_Stats_copy_df['team'].value_counts()
# Out:
# team
# ATL    25
# BOS    25
# UTA    25
# TOR    25
# SAS    25
# SAC    25
# POR    25
# PHO    25
# PHI    25
# ORL    25
# OKC    25
# NYK    25
# MIN    25
# MIL    25
# MIA    25
# MEM    25
# LAL    25
# LAC    25
# IND    25
# HOU    25
# GSW    25
# DET    25
# DEN    25
# DAL    25
# CLE    25
# CHI    25
# NJN    25
# WAS    25
# CHA    23
# NOH    22
# Name: count, dtype: int64

# %%
NBA_Team_Stats_copy_df_noCHA = NBA_Team_Stats_copy_df.loc[NBA_Team_Stats_copy_df["team"] != 'CHA']
NBA_Team_Stats_copy_df_noCHA
# Out:
#     team  season  wins    fg   fga  fg_percent  three_point  three_point_att  \
# 0    ATL    2024    34  43.3  92.8       0.466         13.8             37.7
# 1    ATL    2023    41  44.6  92.4       0.483         10.8             30.5
# 2    ATL    2022    43  41.5  88.3       0.470         12.9             34.4
# 3    ATL    2021    41  40.8  87.2       0.468         12.4             33.4
# 4    ATL    2020    20  40.6  90.6       0.449         12.0             36.1
# ..   ...     ...   ...   ...   ...         ...          ...              ...
# 740  WAS    2004    25  33.6  80.0       0.421          5.3             15.5
# 741  WAS    2003    37  34.3  78.0       0.440          3.1              9.9
# 742  WAS    2002    37  35.8  81.3       0.441          3.7              9.6
# 743  WAS    2001    19  34.5  78.7       0.439          3.4             10.3
# 744  WAS    2000    29  36.7  81.5       0.451          4.1             10.9
#
# ...

# %%
NBA_Team_Stats_copy_df_noCHAnoNOH = NBA_Team_Stats_copy_df_noCHA.loc[NBA_Team_Stats_copy_df["team"] != 'NOH']
NBA_Team_Stats_noCHAnoNOH_df = pd.DataFrame(NBA_Team_Stats_copy_df_noCHAnoNOH)
NBA_Team_Stats_noCHAnoNOH_df
# Out:
#     team  season  wins    fg   fga  fg_percent  three_point  three_point_att  \
# 0    ATL    2024    34  43.3  92.8       0.466         13.8             37.7
# 1    ATL    2023    41  44.6  92.4       0.483         10.8             30.5
# 2    ATL    2022    43  41.5  88.3       0.470         12.9             34.4
# 3    ATL    2021    41  40.8  87.2       0.468         12.4             33.4
# 4    ATL    2020    20  40.6  90.6       0.449         12.0             36.1
# ..   ...     ...   ...   ...   ...         ...          ...              ...
# 740  WAS    2004    25  33.6  80.0       0.421          5.3             15.5
# 741  WAS    2003    37  34.3  78.0       0.440          3.1              9.9
# 742  WAS    2002    37  35.8  81.3       0.441          3.7              9.6
# 743  WAS    2001    19  34.5  78.7       0.439          3.4             10.3
# 744  WAS    2000    29  36.7  81.5       0.451          4.1             10.9
#
# ...

# %%
NBA_Payroll = pd.read_csv('team_salaries.csv')
NBA_Payroll_copy = NBA_Payroll.copy()
NBA_Payrolls_df = pd.DataFrame(NBA_Payroll_copy)
NBA_Payrolls_df
# Out:
#     team  year     salary
# 0    ATL  2000   44169202
# 1    ATL  2001   39297129
# 2    ATL  2002   51525207
# 3    ATL  2003   55711549
# 4    ATL  2004   64497340
# ..   ...   ...        ...
# 748  WAS  2020  129994563
# 749  WAS  2021  129669262
# 750  WAS  2022  127094532
# 751  WAS  2023  150006207
# 752  WAS  2024  143475895
#
# [753 rows x 3 columns]

# %%
NBA_Payrolls_df['team'].value_counts()
# Out:
# team
# NOP    33
# ATL    25
# BOS    25
# UTA    25
# TOR    25
# SAS    25
# SAC    25
# POR    25
# PHO    25
# PHI    25
# ORL    25
# OKC    25
# NYK    25
# MIN    25
# MIL    25
# MIA    25
# MEM    25
# LAL    25
# LAC    25
# IND    25
# HOU    25
# GSW    25
# DET    25
# DEN    25
# DAL    25
# CLE    25
# CHI    25
# BRK    25
# WAS    25
# CHA    20
# Name: count, dtype: int64

# %%
NBA_Payrolls_noCHA = NBA_Payrolls_df.loc[NBA_Payrolls_df["team"] != 'CHA']
NBA_Payrolls_noCHA
# Out:
#     team  year     salary
# 0    ATL  2000   44169202
# 1    ATL  2001   39297129
# 2    ATL  2002   51525207
# 3    ATL  2003   55711549
# 4    ATL  2004   64497340
# ..   ...   ...        ...
# 748  WAS  2020  129994563
# 749  WAS  2021  129669262
# 750  WAS  2022  127094532
# 751  WAS  2023  150006207
# 752  WAS  2024  143475895
#
# [733 rows x 3 columns]

# %%
NBA_Payrolls_noCHAnoNOP = NBA_Payrolls_noCHA.loc[NBA_Payrolls_noCHA["team"] != 'NOP']
NBA_Payrolls_noCHAnoNOP
# Out:
#     team  year     salary
# 0    ATL  2000   44169202
# 1    ATL  2001   39297129
# 2    ATL  2002   51525207
# 3    ATL  2003   55711549
# 4    ATL  2004   64497340
# ..   ...   ...        ...
# 748  WAS  2020  129994563
# 749  WAS  2021  129669262
# 750  WAS  2022  127094532
# 751  WAS  2023  150006207
# 752  WAS  2024  143475895
#
# [700 rows x 3 columns]

# %%
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
NBA_Payrolls_noCHAnoNOP.rename(columns = {'year':'season'}, inplace = True)
display(NBA_Payrolls_noCHAnoNOP)
# Out:
# C:\Users\kzura\AppData\Local\Temp\ipykernel_18240\3459442359.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NBA_Payrolls_noCHAnoNOP.rename(columns = {'year':'season'}, inplace = True)
#     team  season     salary
# 0    ATL    2000   44169202
# 1    ATL    2001   39297129
# 2    ATL    2002   51525207
# 3    ATL    2003   55711549
# 4    ATL    2004   64497340
# ..   ...     ...        ...
# 748  WAS    2020  129994563
# 749  WAS    2021  129669262
# 750  WAS    2022  127094532
# 751  WAS    2023  150006207
# 752  WAS    2024  143475895
#
# [700 rows x 3 columns]

# %%
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

NBA_Team_Stats_with_Payroll = NBA_Team_Stats_noCHAnoNOH_df.merge(NBA_Payrolls_noCHAnoNOP)
NBA_Team_Stats_with_Payroll
# Out:
#     team  season  wins    fg   fga  fg_percent  three_point  three_point_att  \
# 0    ATL    2024    34  43.3  92.8       0.466         13.8             37.7
# 1    ATL    2023    41  44.6  92.4       0.483         10.8             30.5
# 2    ATL    2022    43  41.5  88.3       0.470         12.9             34.4
# 3    ATL    2021    41  40.8  87.2       0.468         12.4             33.4
# 4    ATL    2020    20  40.6  90.6       0.449         12.0             36.1
# ..   ...     ...   ...   ...   ...         ...          ...              ...
# 670  WAS    2004    25  33.6  80.0       0.421          5.3             15.5
# 671  WAS    2003    37  34.3  78.0       0.440          3.1              9.9
# 672  WAS    2002    37  35.8  81.3       0.441          3.7              9.6
# 673  WAS    2001    19  34.5  78.7       0.439          3.4             10.3
# 674  WAS    2000    29  36.7  81.5       0.451          4.1             10.9
#
# ...

# %%
print(NBA_Team_Stats_with_Payroll.dtypes)
# Out:
# team                object
# season               int64
# wins                 int64
# fg                 float64
# fga                float64
# fg_percent         float64
# three_point        float64
# three_point_att    float64
# three_point_per    float64
# two_point          float64
# two_point_att      float64
# two_point_per      float64
# ft                 float64
# ft_att             float64
# ft_per             float64
# o_reb              float64
# d_reb              float64
# tot_reb            float64
# st                 float64
# stl                float64
# blk                float64
# pts                float64
# salary               int64
# dtype: object

# %%
Salary_Cap = pd.read_csv('NBA_Salary_Cap2.csv')
Salary_Cap_df = pd.DataFrame(Salary_Cap)
Salary_Cap_df
# Out:
#     season     salary_cap
# 0   2000.0   $34,000,000
# 1   2001.0   $35,500,000
# 2   2002.0   $42,500,000
# 3   2003.0   $40,271,000
# 4   2004.0   $43,840,000
# 5   2005.0   $43,870,000
# 6   2006.0   $49,500,000
# 7   2007.0   $53,135,000
# 8   2008.0   $55,630,000
# 9   2009.0   $58,680,000
# 10  2010.0   $57,700,000
# 11  2011.0   $58,044,000
# 12  2012.0   $58,044,000
# 13  2013.0   $58,044,000
# 14  2014.0   $58,679,000
# 15  2015.0   $63,065,000
# 16  2016.0   $70,000,000
# 17  2017.0   $94,143,000
# 18  2018.0   $99,093,000
# 19  2019.0  $101,869,000
# 20  2020.0  $109,140,000
# 21  2021.0  $109,140,000
# 22  2022.0  $112,414,000
# 23  2023.0  $123,655,000
# 24  2024.0  $136,021,000
# 25     NaN            NaN
# 26     NaN            NaN
# 27     NaN            NaN
# 28     NaN            NaN
# 29     NaN            NaN
# 30     NaN            NaN
# 31     NaN            NaN
# 32     NaN            NaN
# 33     NaN            NaN
# 34     NaN            NaN
# ...

# %%
Salary_Cap_df = Salary_Cap_df.dropna()
Salary_Cap_df
# Out:
#     season     salary_cap
# 0   2000.0   $34,000,000
# 1   2001.0   $35,500,000
# 2   2002.0   $42,500,000
# 3   2003.0   $40,271,000
# 4   2004.0   $43,840,000
# 5   2005.0   $43,870,000
# 6   2006.0   $49,500,000
# 7   2007.0   $53,135,000
# 8   2008.0   $55,630,000
# 9   2009.0   $58,680,000
# 10  2010.0   $57,700,000
# 11  2011.0   $58,044,000
# 12  2012.0   $58,044,000
# 13  2013.0   $58,044,000
# 14  2014.0   $58,679,000
# 15  2015.0   $63,065,000
# 16  2016.0   $70,000,000
# 17  2017.0   $94,143,000
# 18  2018.0   $99,093,000
# 19  2019.0  $101,869,000
# 20  2020.0  $109,140,000
# 21  2021.0  $109,140,000
# 22  2022.0  $112,414,000
# 23  2023.0  $123,655,000
# 24  2024.0  $136,021,000

# %%
Salary_Cap_df['season'] = Salary_Cap_df['season'].astype('int')
Salary_Cap_df
# Out:
# C:\Users\kzura\AppData\Local\Temp\ipykernel_18240\2426223275.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Salary_Cap_df['season'] = Salary_Cap_df['season'].astype('int')
#     season     salary_cap
# 0     2000   $34,000,000
# 1     2001   $35,500,000
# 2     2002   $42,500,000
# 3     2003   $40,271,000
# 4     2004   $43,840,000
# 5     2005   $43,870,000
# 6     2006   $49,500,000
# 7     2007   $53,135,000
# 8     2008   $55,630,000
# 9     2009   $58,680,000
# 10    2010   $57,700,000
# 11    2011   $58,044,000
# 12    2012   $58,044,000
# 13    2013   $58,044,000
# 14    2014   $58,679,000
# 15    2015   $63,065,000
# 16    2016   $70,000,000
# 17    2017   $94,143,000
# 18    2018   $99,093,000
# 19    2019  $101,869,000
# ...

# %%
NBA_Team_Stats_with_Payroll = NBA_Team_Stats_with_Payroll.merge(Salary_Cap_df)
NBA_Team_Stats_with_Payroll
# Out:
#     team  season  wins    fg   fga  fg_percent  three_point  three_point_att  \
# 0    ATL    2024    34  43.3  92.8       0.466         13.8             37.7
# 1    BOS    2024    57  43.8  90.2       0.486         16.6             42.5
# 2    CHI    2024    35  41.8  89.4       0.467         11.6             32.4
# 3    CLE    2024    45  41.8  87.2       0.479         13.7             37.3
# 4    DAL    2024    44  43.3  89.7       0.483         14.6             39.3
# ..   ...     ...   ...   ...   ...         ...          ...              ...
# 670  SAC    2000    44  40.0  88.9       0.450          6.5             20.2
# 671  SAS    2000    53  36.0  78.0       0.462          4.0             10.8
# 672  TOR    2000    45  36.3  83.9       0.433          5.2             14.3
# 673  UTA    2000    55  36.1  77.8       0.464          4.0             10.4
# 674  WAS    2000    29  36.7  81.5       0.451          4.1             10.9
#
# ...

# %%
print(NBA_Team_Stats_with_Payroll.dtypes)
# Out:
# team                object
# season               int64
# wins                 int64
# fg                 float64
# fga                float64
# fg_percent         float64
# three_point        float64
# three_point_att    float64
# three_point_per    float64
# two_point          float64
# two_point_att      float64
# two_point_per      float64
# ft                 float64
# ft_att             float64
# ft_per             float64
# o_reb              float64
# d_reb              float64
# tot_reb            float64
# st                 float64
# stl                float64
# blk                float64
# pts                float64
# salary               int64
# salary_cap          object
# dtype: object

# %%
NBA_Team_Stats_with_Payroll['salary_cap'] = NBA_Team_Stats_with_Payroll['salary_cap'].str.replace('$', '')
NBA_Team_Stats_with_Payroll
# Out:
#     team  season  wins    fg   fga  fg_percent  three_point  three_point_att  \
# 0    ATL    2024    34  43.3  92.8       0.466         13.8             37.7
# 1    BOS    2024    57  43.8  90.2       0.486         16.6             42.5
# 2    CHI    2024    35  41.8  89.4       0.467         11.6             32.4
# 3    CLE    2024    45  41.8  87.2       0.479         13.7             37.3
# 4    DAL    2024    44  43.3  89.7       0.483         14.6             39.3
# ..   ...     ...   ...   ...   ...         ...          ...              ...
# 670  SAC    2000    44  40.0  88.9       0.450          6.5             20.2
# 671  SAS    2000    53  36.0  78.0       0.462          4.0             10.8
# 672  TOR    2000    45  36.3  83.9       0.433          5.2             14.3
# 673  UTA    2000    55  36.1  77.8       0.464          4.0             10.4
# 674  WAS    2000    29  36.7  81.5       0.451          4.1             10.9
#
# ...

# %%
NBA_Team_Stats_with_Payroll['salary_cap'] = NBA_Team_Stats_with_Payroll['salary_cap'].str.replace(',', '').astype(float)

# %%
NBA_Team_Stats_with_Payroll
# Out:
#     team  season  wins    fg   fga  fg_percent  three_point  three_point_att  \
# 0    ATL    2024    34  43.3  92.8       0.466         13.8             37.7
# 1    BOS    2024    57  43.8  90.2       0.486         16.6             42.5
# 2    CHI    2024    35  41.8  89.4       0.467         11.6             32.4
# 3    CLE    2024    45  41.8  87.2       0.479         13.7             37.3
# 4    DAL    2024    44  43.3  89.7       0.483         14.6             39.3
# ..   ...     ...   ...   ...   ...         ...          ...              ...
# 670  SAC    2000    44  40.0  88.9       0.450          6.5             20.2
# 671  SAS    2000    53  36.0  78.0       0.462          4.0             10.8
# 672  TOR    2000    45  36.3  83.9       0.433          5.2             14.3
# 673  UTA    2000    55  36.1  77.8       0.464          4.0             10.4
# 674  WAS    2000    29  36.7  81.5       0.451          4.1             10.9
#
# ...

# %%
print(NBA_Team_Stats_with_Payroll.dtypes)
# Out:
# team                object
# season               int64
# wins                 int64
# fg                 float64
# fga                float64
# fg_percent         float64
# three_point        float64
# three_point_att    float64
# three_point_per    float64
# two_point          float64
# two_point_att      float64
# two_point_per      float64
# ft                 float64
# ft_att             float64
# ft_per             float64
# o_reb              float64
# d_reb              float64
# tot_reb            float64
# st                 float64
# stl                float64
# blk                float64
# pts                float64
# salary               int64
# salary_cap         float64
# dtype: object

# %%
def Wins_V_Payroll_2(team_name):
    # Assuming NBA_Team_Stats_with_Payroll is defined elsewhere in your code
    df = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == team_name]

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 8))

    # Plot 'Wins' on the left
    ax1.plot(df['season'], df['wins'], color='black', linestyle='-', marker='o', label='Wins')
    ax1.set_xlabel('NBA Season')
    # ax1.set_ylabel('Wins')
    ax1.set_title(f"{team_name} Wins", fontsize = 'x-large')
    ax1.grid(True)
    ax1.tick_params('x', rotation=45)
    ax1.set_yticks(np.arange(0, 75, 10))
    ax1.set_ylim(0, 80)
    ax1.plot(df['season'], [41] * len(df), linestyle='dashed', color='orange', marker= ',', label='41 Wins (.500 Record)')

    # Plot 'Payroll' and 'Salary Cap' on the right
    ax2.plot(df['season'], df['salary']/1000000, color='green', linestyle='dashed', marker='s', label='Payroll (in Millions of USD)')
    ax2.plot(df['season'], df['salary_cap']/1000000, color='red', linestyle='dotted', marker='^', label='Salary Cap (in Millions of USD)')
    ax2.set_xlabel('NBA Season')
    # ax2.set_ylabel('Dollars (in Millions)', fontsize = 'x-large')
    ax2.set_title(f"{team_name} Payroll and Salary Cap", fontsize = 'x-large')
    ax2.legend(fontsize = 'large', loc = 'upper left')
    ax2.grid(True)
    ax2.tick_params('x', which = 'both', rotation=45)
    ax2.set_yticks(np.arange(0, 205, 20))
    ax2.set_ylim(0, 205)

    plt.tight_layout()
    plt.show()

# %%
print(NBA_Team_Stats_with_Payroll['team'].unique())
# Out:
# ['ATL' 'BOS' 'CHI' 'CLE' 'DAL' 'DEN' 'DET' 'GSW' 'HOU' 'IND' 'LAC' 'LAL'
#  'MEM' 'MIA' 'MIL' 'MIN' 'NYK' 'OKC' 'ORL' 'PHI' 'PHO' 'POR' 'SAC' 'SAS'
#  'TOR' 'UTA' 'WAS']

# %%
Wins_V_Payroll_2('ATL')

# %%
Wins_V_Payroll_2('BOS')

# %%
Wins_V_Payroll_2('CHI')

# %%
Wins_V_Payroll_2('DAL')

# %%
Wins_V_Payroll_2('DEN')

# %%
Wins_V_Payroll_2('DET')

# %%
Wins_V_Payroll_2('GSW')

# %%
Wins_V_Payroll_2('HOU')

# %%
Wins_V_Payroll_2('IND')

# %%
Wins_V_Payroll_2('LAC')

# %%
Wins_V_Payroll_2('LAL')

# %%
Wins_V_Payroll_2('MEM')

# %%
Wins_V_Payroll_2('MIA')

# %%
Wins_V_Payroll_2('MIL')

# %%
Wins_V_Payroll_2('MIN')

# %%
Wins_V_Payroll_2('NYK')

# %%
Wins_V_Payroll_2('OKC')

# %%
Wins_V_Payroll_2('ORL')

# %%
Wins_V_Payroll_2('PHI')

# %%
Wins_V_Payroll_2('PHO')

# %%
Wins_V_Payroll_2('POR')

# %%
Wins_V_Payroll_2('SAC')

# %%
Wins_V_Payroll_2('SAS')

# %%
Wins_V_Payroll_2('TOR')

# %%
Wins_V_Payroll_2('UTA')

# %%
Wins_V_Payroll_2('WAS')

# %%
def Wins_V_Payroll(team_name):
    df = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == team_name]

    fig, ax1 = plt.subplots(figsize=(12, 5))
    ax1.plot(df['season'], df['salary']/1000000, color='green', linestyle='dashed', marker='s', label= 'Payroll in $Millions')
    ax1.plot(df['season'], df['wins'], color='black', linestyle='-', marker='o', label= 'Wins')
    ax1.plot(df['season'], df['salary_cap']/1000000, color='red', linestyle='dotted', marker='^', label= 'Salary Cap')
    ax1.set_xlabel('NBA Season')
    # ax1.set_ylabel('Value', labelpad=20, fontsize='large')
    ax1.set_title(f"{team_name} Wins to Payroll Comparison", fontsize='x-large')
    # ax1.plot(df['season'], [41] * len(df), linestyle='dotted', color='orange', marker= ',', label='41 Wins (.500 Record)')
    ax1.legend(fontsize='x-small')
    ax1.spines['top'].set_visible(False)
    ax1.spines['right'].set_visible(False)
    ax1.spines['left'].set_visible(False)
    ax1.grid(axis='y')
    plt.xticks(df['season'], rotation=45)
    plt.tight_layout()
    plt.show()

# %%
Wins_V_Payroll('ATL')

# %%
Wins_V_Payroll('BOS')

# %%
Wins_V_Payroll('CLE')

# %%
Wins_V_Payroll('DAL')

# %%
Wins_V_Payroll('DEN')

# %%
Wins_V_Payroll('MIA')

# %%
print(NBA_Team_Stats_with_Payroll['team'].unique())

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

df = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == 'NYK']
ax1.plot(df['season'], df['salary']/1000000, color='orange', linestyle='--', marker='o', label= 'Payroll in $Millions')
ax1.plot(df['season'], df['wins'], color='darkblue', linestyle='--', marker='o', label= 'Wins')
ax1.set_xlabel('NBA Season')
ax1.set_ylabel('Value', labelpad=20, fontsize='large')
ax1.set_title("Knicks' Payroll v. Wins", fontsize='x-large')
# ax1.plot(df['season'], [41] * len(df), linestyle='--', color='black', label='41 Wins (.500 Record)')
ax1.legend(fontsize='x-small')
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['left'].set_visible(False)
plt.xticks(df['season'], rotation = 45)
ax1.grid(axis = 'y')
plt.tight_layout()
plt.show()

# %%
df1 = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == 'ORL']

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(df1['season'], df1['salary']/1000000, color='silver', linestyle='--', marker='o', label= 'Payroll in $Millions')
ax1.plot(df1['season'], df1['wins'], color='blue', linestyle='--', marker='o', label= 'Wins')
ax1.set_xlabel('NBA Season')
ax1.set_ylabel('Value', labelpad=20, fontsize='large')
ax1.set_title("Magic' Payroll v. Wins", fontsize='x-large')
# ax1.plot(df['season'], [41] * len(df), linestyle='--', color='black', label='41 Wins (.500 Record)')
ax1.legend(fontsize='x-small')
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['left'].set_visible(False)
plt.xticks(df['season'], rotation = 45)
ax1.grid(axis = 'y')
plt.tight_layout()
plt.show()

# %%
def Wins_V_Payroll(team_name):
    df = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == team_name]

    fig, ax1 = plt.subplots(figsize=(10, 6))
    ax1.plot(df['season'], df['salary']/1000000, color='green', linestyle='-', marker='s', label= 'Payroll in $Millions')
    ax1.plot(df['season'], df['wins'], color='black', linestyle='-', marker='s', label= 'Wins')
    ax1.plot(df['season'], df['salary_cap']/1000000, color='red', linestyle='-', marker='o', label= 'Salary Cap')
    ax1.set_xlabel('NBA Season')
    ax1.set_ylabel('Value', labelpad=20, fontsize='large')
    ax1.set_title(f"{team_name} Wins to Payroll Comparison", fontsize='x-large')
    ax1.plot(df['season'], [41] * len(df), linestyle='--', color='orange', label='41 Wins (.500 Record)')
    ax1.legend(fontsize='x-small')
    ax1.spines['top'].set_visible(False)
    ax1.spines['right'].set_visible(False)
    ax1.spines['left'].set_visible(False)
    ax1.grid(axis='y')
    plt.xticks(df['season'], rotation=45)
    plt.tight_layout()
    plt.show()

# Example usage:
# team_name = 'ORL'  # Change this to the desired team name
# plot_team_stats(team_name)

# %%
# Creating the first subplot for Knicks data
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10), sharey=True)

# Plotting Knicks data
df = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == 'NYK']
ax1.plot(df['season'], df['salary']/1000000, color='orange', linestyle='--', marker='o', label='Payroll in $Millions')
ax1.plot(df['season'], df['wins'], color='darkblue', linestyle='--', marker='o', label="Knicks Wins")
ax1.set_xlabel('NBA Season')
ax1.set_ylabel('Value', labelpad=20, fontsize='large')
ax1.set_title("Knicks Payroll v. Wins", fontsize='x-large')
ax1.legend(fontsize='small')
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.grid(axis='y')

# Plotting Magic data
df1 = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == 'ORL']
ax2.plot(df1['season'], df1['salary']/1000000, color='silver', linestyle='--', marker='o', label='Payroll in $Millions')
ax2.plot(df1['season'], df1['wins'], color='blue', linestyle='--', marker='o', label= "Magic Wins")
ax2.set_xlabel('NBA Season')
ax2.set_ylabel('Value', labelpad=20, fontsize='large')
ax2.set_title("Magic Payroll v. Wins", fontsize='x-large')
ax2.legend(fontsize='small')
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax2.grid(axis='y')

ax1.set_xticks(df['season'])
ax1.tick_params(axis='x', rotation=45)
ax2.set_xticks(df['season'])
ax2.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.show()

# %%
print(NBA_Team_Stats_with_Payroll.columns)

# %%
# Plotting Lakers data
df_lakers = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == 'LAL']
ax1.plot(df_lakers['season'], df_lakers['wins'], color='yellow', linestyle='-', marker='o', label="Lakers Wins")
ax1.plot(df_lakers['season'], df_lakers['salary']/1000000, color='green', linestyle='--', marker='o', label='Payroll in $Millions')
ax1.set_xlabel('NBA Season')
# ax1.set_ylabel('Wins', labelpad=20, fontsize='large')
ax1.set_title("Lakers Wins", fontsize='x-large')
ax1.legend(fontsize='medium')
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.grid(axis='y')
ax1.set_xticks(df_lakers['season'])
ax1.set_xticklabels(df_lakers['season'], rotation=45)

# Plotting Clippers data
df_clippers = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == 'LAC']
ax2.plot(df_clippers['season'], df_clippers['wins'], color='red', linestyle='-', marker='o', label="Clippers Wins")
ax2.plot(df_clippers['season'], df_clippers['salary']/1000000, color='green', linestyle='--', marker='o', label='Payroll in $Millions')
ax2.set_xlabel('NBA Season')
ax2.set_title("Clippers Wins", fontsize='x-large')
ax2.legend(fontsize='medium')
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax2.grid(axis='y')
ax2.set_xticks(df_clippers['season'])
ax2.set_xticklabels(df_clippers['season'], rotation=45)

# Plotting Warriors data
df_warriors = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == 'GSW']
ax3.plot(df_warriors['season'], df_warriors['wins'], color='blue', linestyle='-', marker='o', label="Warriors Wins")
ax3.plot(df_warriors['season'], df_warriors['salary']/1000000, color='green', linestyle='--', marker='o', label='Payroll in $Millions')
ax3.set_xlabel('NBA Season')
# ax3.set_ylabel('Wins', labelpad=20, fontsize='large')
ax3.set_title("Warriors Wins", fontsize='x-large')
ax3.legend(fontsize='medium')
ax3.spines['top'].set_visible(False)
ax3.spines['right'].set_visible(False)
ax3.spines['left'].set_visible(False)
ax3.grid(axis='y')
ax3.set_xticks(df_warriors['season'])
ax3.set_xticklabels(df_warriors['season'], rotation=45)

# Plotting Kings data
df_kings = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == 'SAC']
ax4.plot(df_kings['season'], df_kings['wins'], color='silver', linestyle='-', marker='o', label="Kings Wins")
ax4.plot(df_lakers['season'], df_kings['salary']/1000000, color='green', linestyle='--', marker='o', label='Payroll in $Millions')
ax4.set_xlabel('NBA Season')
ax4.set_title("Kings Wins", fontsize='x-large')
ax4.legend(fontsize='medium')
ax4.spines['top'].set_visible(False)
ax4.spines['right'].set_visible(False)
ax4.spines['left'].set_visible(False)
ax4.grid(axis='y')
ax4.set_xticks(df_kings['season'])
ax4.set_xticklabels(df_kings['season'], rotation=45)

# Adjusting layout
plt.tight_layout()
plt.show()

# %%
# Creating the first subplot
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10), sharey=True)

# Plotting Lakers data
df3 = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == 'LAL']
# ax1.plot(df['season'], df3['salary']/1000000, color='yellow', linestyle='--', marker='o', label='Payroll in $Millions')
ax1.plot(df['season'], df3['wins'], color='purple', linestyle='--', marker='o', label="Lakers Wins")
ax1.plot(df['season'], df3['tot_reb'], color='yellow', linestyle='--', marker='o', label="Lakers Rebounds")
ax1.set_xlabel('NBA Season')
ax1.set_ylabel('Dollars or Wins', labelpad=20, fontsize='large')
ax1.set_title("Lakers Payroll v. Wins", fontsize='x-large')
ax1.legend(fontsize='small')
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.grid(axis='y')

# Plotting Clippers data
df4 = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == 'LAC']
# .plot(df1['season'], df4['salary']/1000000, color='red', linestyle='--', marker='o', label='Payroll in $Millions')
ax2.plot(df1['season'], df4['wins'], color='blue', linestyle='--', marker='o', label= "Clippers Wins")
ax2.plot(df1['season'], df4['tot_reb'], color='red', linestyle='--', marker='o', label= "Clippers Rebounds")
ax2.set_xlabel('NBA Season')
# ax2.set_ylabel('Value', labelpad=20, fontsize='large')
ax2.set_title("Clippers Payroll v. Wins", fontsize='x-large')
ax2.legend(fontsize='small')
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax2.grid(axis='y')

ax1.set_xticks(df['season'])
ax1.tick_params(axis='x', rotation=45)
ax2.set_xticks(df['season'])
ax2.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.show()

# %%
# df5 = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == 'GSW']
# df6 = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == 'SAC']
# 
# fig, ax1 = plt.subplots(figsize=(10, 6))
#  
# ax1.plot(df3['season'], df3['wins'], color='yellow', linestyle='--', marker='s', label= 'Lakers Wins')
# ax1.plot(df4['season'], df4['wins'], color='red', linestyle='--', marker='s', label= 'Clippers Wins')
# ax1.plot(df5['season'], df5['wins'], color='blue', linestyle='--', marker='s', label= 'Warriors Wins')
# ax1.plot(df6['season'], df6['wins'], color='purple', linestyle='--', marker='s', label= 'Kings Wins')
# 
# ax1.set_xlabel('NBA Season')
# ax1.set_ylabel('Value', labelpad=20, fontsize='large')
# ax1.set_title("The Battle for California", fontsize='x-large')
# # ax1.plot(df['season'], [41] * len(df), linestyle='--', color='black', label='41 Wins (.500 Record)')
# ax1.legend(fontsize='small')
# ax1.spines['top'].set_visible(False)
# ax1.spines['right'].set_visible(False)
# ax1.spines['left'].set_visible(False)
# plt.xticks(df['season'], rotation = 45)
# ax1.grid(axis = 'x')
# plt.tight_layout()
# plt.show()

# Creating the subplots
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(18, 12), sharey=True)

# Plotting Lakers data
df_lakers = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == 'LAL']
ax1.plot(df_lakers['season'], df_lakers['wins'], color='yellow', linestyle='-', marker='o', label="Lakers Wins")
ax1.plot(df_lakers['season'], df_lakers['salary']/1000000, color='green', linestyle='--', marker='o', label='Payroll in $Millions')
ax1.set_xlabel('NBA Season')
# ax1.set_ylabel('Wins', labelpad=20, fontsize='large')
ax1.set_title("Lakers Wins", fontsize='x-large')
ax1.legend(fontsize='medium')
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.grid(axis='y')
ax1.set_xticks(df_lakers['season'])
ax1.set_xticklabels(df_lakers['season'], rotation=45)

# Plotting Clippers data
df_clippers = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == 'LAC']
ax2.plot(df_clippers['season'], df_clippers['wins'], color='red', linestyle='-', marker='o', label="Clippers Wins")
ax2.plot(df_clippers['season'], df_clippers['salary']/1000000, color='green', linestyle='--', marker='o', label='Payroll in $Millions')
ax2.set_xlabel('NBA Season')
ax2.set_title("Clippers Wins", fontsize='x-large')
ax2.legend(fontsize='medium')
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax2.grid(axis='y')
ax2.set_xticks(df_clippers['season'])
ax2.set_xticklabels(df_clippers['season'], rotation=45)

# Plotting Warriors data
df_warriors = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == 'GSW']
ax3.plot(df_warriors['season'], df_warriors['wins'], color='blue', linestyle='-', marker='o', label="Warriors Wins")
ax3.plot(df_warriors['season'], df_warriors['salary']/1000000, color='green', linestyle='--', marker='o', label='Payroll in $Millions')
ax3.set_xlabel('NBA Season')
# ax3.set_ylabel('Wins', labelpad=20, fontsize='large')
ax3.set_title("Warriors Wins", fontsize='x-large')
ax3.legend(fontsize='medium')
ax3.spines['top'].set_visible(False)
ax3.spines['right'].set_visible(False)
ax3.spines['left'].set_visible(False)
ax3.grid(axis='y')
ax3.set_xticks(df_warriors['season'])
ax3.set_xticklabels(df_warriors['season'], rotation=45)

# Plotting Kings data
df_kings = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == 'SAC']
ax4.plot(df_kings['season'], df_kings['wins'], color='silver', linestyle='-', marker='o', label="Kings Wins")
ax4.plot(df_lakers['season'], df_kings['salary']/1000000, color='green', linestyle='--', marker='o', label='Payroll in $Millions')
ax4.set_xlabel('NBA Season')
ax4.set_title("Kings Wins", fontsize='x-large')
ax4.legend(fontsize='medium')
ax4.spines['top'].set_visible(False)
ax4.spines['right'].set_visible(False)
ax4.spines['left'].set_visible(False)
ax4.grid(axis='y')
ax4.set_xticks(df_kings['season'])
ax4.set_xticklabels(df_kings['season'], rotation=45)

# Adjusting layout
plt.tight_layout()
plt.show()

# %%
# Filter data for specific teams
teams = ['LAL', 'LAC', 'GSW', 'SAC']
df_teams = NBA_Team_Stats_with_Payroll[NBA_Team_Stats_with_Payroll['team'].isin(teams)]

# Reshape the DataFrame
df_melted = pd.melt(df_teams, id_vars=['season', 'team'], value_vars=['wins'])

# Define colors for each team
team_colors = {'LAL': 'yellow', 'LAC': 'red', 'GSW': 'blue', 'SAC': 'grey'}
team_order = ['LAL', 'LAC', 'GSW', 'SAC']

# Create the grouped bar plot
plt.figure(figsize=(10, 6))
sns.barplot(data=df_melted, x='season', y='value', hue='team', palette=team_colors,
            saturation=3, errorbar=None, hue_order=team_order)
plt.title('The Battle for California')
plt.xlabel('NBA Season')
plt.ylabel('Wins')
plt.grid(True, axis='y', linestyle='--', alpha=0.5)
plt.legend(title='Team', loc='upper right')
plt.xticks(rotation=45)
sns.set_style("whitegrid")
sns.despine(top=True, right=True)
plt.tight_layout()
plt.show()

# %%
teams = ['LAL', 'LAC', 'GSW', 'SAC']
df_teams = NBA_Team_Stats_with_Payroll[NBA_Team_Stats_with_Payroll['team'].isin(teams)]

# Reshape the DataFrame
df_melted = pd.melt(df_teams, id_vars=['season', 'team'], value_vars=['wins'])

# Define colors for each team
team_colors = {'LAL': 'purple', 'LAC': 'red', 'GSW': 'yellow', 'SAC': 'silver'}

# Set the order of teams
team_order = ['LAL', 'LAC', 'GSW', 'SAC']

# Create the scatter plot with specified hue order
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_melted, x='season', y='value', hue='team', palette=team_colors, hue_order=team_order)
plt.title('Wins by NBA Team')
plt.xlabel('NBA Season')
plt.ylabel('Wins')
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(title='Team', loc='upper right')
plt.xticks(rotation=45)
sns.set_style("whitegrid")
sns.despine(top=True, right=True)
plt.tight_layout()
plt.show()

# %%
# fig, ax1 = plt.subplots(figsize=(10, 6))
# 
# df3 = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == 'LAL']
# df4 = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == 'LAC']
# df5 = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == 'GSW']
# df6 = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == 'SAC']
#  
# ax1.plot(df3['season'], df3['wins'], color='yellow', linestyle='-', marker='s', label= 'Lakers Wins')
# ax1.plot(df4['season'], df4['wins'], color='red', linestyle='-', marker='s', label= 'Clippers Wins')
# ax1.plot(df5['season'], df5['wins'], color='blue', linestyle='-', marker='s', label= 'Warriors Wins')
# ax1.plot(df6['season'], df6['wins'], color='purple', linestyle='-', marker='s', label= 'Kings Wins')
# 
# ax1.set_xlabel('NBA Season')
# ax1.set_ylabel('Value', labelpad=20, fontsize='large')
# ax1.set_title("The Battle for Staples or Crypto", fontsize='x-large')
# # ax1.plot(df['season'], [41] * len(df), linestyle='--', color='black', label='41 Wins (.500 Record)')
# ax1.legend(fontsize='small')
# ax1.spines['top'].set_visible(False)
# ax1.spines['right'].set_visible(False)
# ax1.spines['left'].set_visible(False)
# plt.xticks(df['season'], rotation = 45)
# ax1.grid(axis = 'y')
# plt.tight_layout()
# plt.show()
 
# # Filter data for specific teams
# df3 = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == 'LAL']
# df4 = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == 'LAC']
# df5 = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == 'GSW']
# df6 = NBA_Team_Stats_with_Payroll.loc[NBA_Team_Stats_with_Payroll['team'] == 'SAC']
# 
# # Create traces for each team
# trace1 = go.Bar(x=df3['season'], y=df3['wins'], name='Lakers', marker=dict(color='yellow'))
# trace2 = go.Bar(x=df4['season'], y=df4['wins'], name='Clippers', marker=dict(color='red'))
# trace3 = go.Bar(x=df5['season'], y=df5['wins'], name='Warriors', marker=dict(color='blue'))
# trace4 = go.Bar(x=df6['season'], y=df6['wins'], name='Kings', marker=dict(color='purple'))
# 
# # Create figure layout
# layout = go.Layout(title='Wins by NBA Team',
#                    xaxis=dict(title='NBA Season'),
#                    yaxis=dict(title='Wins'),
#                    barmode='group')
# 
# # Create figure object
# fig = go.Figure(data=[trace1, trace2, trace3, trace4], layout=layout)
# 
# # Show the plot
# fig.show()

# %%
# # COMPARE 4 CALIFORNIA TEAMS
# # Filter data for specific teams
# teams = ['LAL', 'LAC', 'GSW', 'SAC']
# df_teams = NBA_Team_Stats_with_Payroll[NBA_Team_Stats_with_Payroll['team'].isin(teams)]
# 
# # Sort the DataFrame by season
# df_teams_sorted = df_teams.sort_values(by='season')
# 
# # Reshape the DataFrame
# df_melted = pd.melt(df_teams_sorted, id_vars=['season', 'team'], value_vars=['wins'])
# 
# # Define colors for each team
# team_colors = {'LAL': 'yellow', 'LAC': 'red', 'GSW': 'blue', 'SAC': 'purple'}
# 
# # Create the grouped bar plot
# plt.figure(figsize=(12, 6))  # Adjust the figure size if needed
# sns.barplot(data=df_melted, x='season', y='value', hue='team', palette=team_colors, 
#             saturation=0.7, errorbar=None)  # Use errorbar=None to remove confidence intervals
# plt.title('Wins by NBA Team')
# plt.xlabel('NBA Season')
# plt.ylabel('Wins')
# 
# # Remove top and right spines
# sns.despine(top=True, right=True)
# 
# plt.legend(title='Team', loc='upper left', bbox_to_anchor=(1, 1))  # Adjust the legend position if needed
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()

# %%
# fig, ax1 = plt.subplots(figsize=(10, 6))
#  
# ax1.plot(San_Antonio_Spurs_Payroll_df['year'], San_Antonio_Spurs_Payroll_df['salary']/1000000,
#          color='red', linestyle='--', marker='o', label= 'Payroll in $Millions')
# 
# # ax1.plot(San_Antonio_Spurs_df['season'], San_Antonio_Spurs_df['three_point_att'],
# #          color='black', linestyle='--', marker='o', label= '3PA')
# 
# # ax1.plot(San_Antonio_Spurs_df['season'], San_Antonio_Spurs_df['three_point'],
# #          color='red', linestyle='--', marker='o', label= '3PM')
# 
# ax1.plot(San_Antonio_Spurs_df['season'], San_Antonio_Spurs_df['wins'],
#          color='silver', linestyle='--', marker='o', label= 'Wins')
# 
# ax1.set_xlabel('NBA Season')
# ax1.set_ylabel('Value', labelpad=20, fontsize='large')
# ax1.set_title("Spurs' Payroll v. Wins", fontsize='x-large')
# # ax1.plot(df['season'], [41] * len(df), linestyle='--', color='black', label='41 Wins (.500 Record)')
# ax1.legend(fontsize='x-small')
# ax1.spines['top'].set_visible(False)
# ax1.spines['right'].set_visible(False)
# ax1.spines['left'].set_visible(False)
# plt.xticks(San_Antonio_Spurs_df['season'], rotation = 45)
# ax1.grid(axis = 'y')
# plt.tight_layout()
# plt.show()

# %%
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# NBA_Team_Stats_wPayroll_df = NBA_Team_Stats_wPayroll_df.astype({'salary' : float})
# display(NBA_Team_Stats_wPayroll_df)

# %%
# NBA_Payrolls_LinedUp_df = NBA_Payrolls_df.iloc[:, ::-1]
# NBA_Payrolls_LinedUp_df

# %%
# NBA_Team_Stats_Cleaned_df = NBA_Team_Stats_with_Payroll.dropna()
# NBA_Team_Stats_Cleaned_df

# %%
# NewYorkKnicks_df = NBA_Team_Stats_copy_df.loc[NBA_Team_Stats_copy_df['team'] == 'NYK']
# NewYorkKnicks_df

# %%
# NewYorkKnicksPayroll_df = NBA_Payrolls_df.loc[NBA_Payrolls_df['team'] == 'NYK']
# NewYorkKnicksPayroll_df

# %%
# NBA_Payrolls_Flipped_df = NBA_Payrolls_df['year'].iloc[::-1]
# NBA_Payrolls_Flipped_df

# %%
# Atlanta_Hawks_df = NBA_Team_Stats_copy_df.loc[NBA_Team_Stats_copy_df['team'] == 'ATL']
# Atlanta_Hawks_df

# %%
# San_Antonio_Spurs_df = NBA_Team_Stats_copy_df.loc[NBA_Team_Stats_copy_df['team'] == 'SAS']
# San_Antonio_Spurs_df

# %%
# San_Antonio_Spurs_Payroll_df = NBA_Payrolls_df.loc[NBA_Payrolls_df['team'] == 'SAS']
# San_Antonio_Spurs_Payroll_df
