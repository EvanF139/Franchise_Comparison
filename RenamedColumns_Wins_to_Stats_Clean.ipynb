# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

# %%
All_Team_Stats = pd.read_csv('team_season_stat_lines.csv')
All_Team_Stats_Copy = All_Team_Stats.copy()
All_Team_Stats_df = pd.DataFrame(All_Team_Stats_Copy)
All_Team_Stats_df
# Out:
#     team  season  wins    fg   fga  fg_percent  three_point  three_point_att  \
# 0    ATL    2024    35  43.2  92.6       0.467         13.8             37.7
# 1    ATL    2023    41  44.6  92.4       0.483         10.8             30.5
# 2    ATL    2022    43  41.5  88.3       0.470         12.9             34.4
# 3    ATL    2021    41  40.8  87.2       0.468         12.4             33.4
# 4    ATL    2020    20  40.6  90.6       0.449         12.0             36.1
# ..   ...     ...   ...   ...   ...         ...          ...              ...
# 740  WAS    2004    25  33.6  80.0       0.421          5.3             15.5
# 741  WAS    2003    37  34.3  78.0       0.440          3.1              9.9
# 742  WAS    2002    37  35.8  81.3       0.441          3.7              9.6
# 743  WAS    2001    19  34.5  78.7       0.439          3.4             10.3
# 744  WAS    2000    29  36.7  81.5       0.451          4.1             10.9
#
#      three_point_per  two_point  ...  ft_att  ft_per  o_reb  d_reb  tot_reb  \
# 0              0.367       29.4  ...    23.5   0.801   12.7   31.4     44.1
# 1              0.352       33.9  ...    22.6   0.818   11.2   33.2     44.4
# 2              0.374       28.6  ...    22.3   0.812   10.0   33.9     44.0
# 3              0.373       28.4  ...    24.2   0.812   10.6   35.1     45.6
# 4              0.333       28.6  ...    23.4   0.790    9.9   33.4     43.3
# ..               ...        ...  ...     ...     ...    ...    ...      ...
# 740            0.341       28.4  ...    27.0   0.714   13.6   29.2     42.8
# 741            0.312       31.3  ...    25.3   0.779   11.2   29.2     40.4
# 742            0.388       32.1  ...    22.8   0.765   12.9   29.2     42.0
# 743            0.324       31.2  ...    27.4   0.759   12.4   28.9     41.3
# 744            0.376       32.6  ...    25.7   0.743   13.0   29.7     42.7
#
#       ast  stl  blk   tov    pts
# 0    26.4  7.5  4.6  13.0  119.1
# 1    25.0  7.1  4.9  12.9  118.4
# 2    24.6  7.2  4.2  11.9  113.9
# 3    24.1  7.0  4.8  13.2  113.7
# 4    24.0  7.8  5.1  16.2  111.8
# ..    ...  ...  ...   ...    ...
# 740  18.7  8.9  5.0  17.5   91.8
# 741  19.7  7.6  4.8  13.4   91.5
# 742  20.9  7.0  4.3  13.0   92.8
# 743  20.1  7.7  4.7  17.0   93.2
# 744  21.6  7.2  4.7  16.1   96.6
#
# [745 rows x 23 columns]

# %%
All_Team_Stats_df['team'].replace('NOH', 'NOP', inplace=True)
All_Team_Stats_df
# Out:
#     team  season  wins    fg   fga  fg_percent  three_point  three_point_att  \
# 0    ATL    2024    35  43.2  92.6       0.467         13.8             37.7
# 1    ATL    2023    41  44.6  92.4       0.483         10.8             30.5
# 2    ATL    2022    43  41.5  88.3       0.470         12.9             34.4
# 3    ATL    2021    41  40.8  87.2       0.468         12.4             33.4
# 4    ATL    2020    20  40.6  90.6       0.449         12.0             36.1
# ..   ...     ...   ...   ...   ...         ...          ...              ...
# 740  WAS    2004    25  33.6  80.0       0.421          5.3             15.5
# 741  WAS    2003    37  34.3  78.0       0.440          3.1              9.9
# 742  WAS    2002    37  35.8  81.3       0.441          3.7              9.6
# 743  WAS    2001    19  34.5  78.7       0.439          3.4             10.3
# 744  WAS    2000    29  36.7  81.5       0.451          4.1             10.9
#
#      three_point_per  two_point  ...  ft_att  ft_per  o_reb  d_reb  tot_reb  \
# 0              0.367       29.4  ...    23.5   0.801   12.7   31.4     44.1
# 1              0.352       33.9  ...    22.6   0.818   11.2   33.2     44.4
# 2              0.374       28.6  ...    22.3   0.812   10.0   33.9     44.0
# 3              0.373       28.4  ...    24.2   0.812   10.6   35.1     45.6
# 4              0.333       28.6  ...    23.4   0.790    9.9   33.4     43.3
# ..               ...        ...  ...     ...     ...    ...    ...      ...
# 740            0.341       28.4  ...    27.0   0.714   13.6   29.2     42.8
# 741            0.312       31.3  ...    25.3   0.779   11.2   29.2     40.4
# 742            0.388       32.1  ...    22.8   0.765   12.9   29.2     42.0
# 743            0.324       31.2  ...    27.4   0.759   12.4   28.9     41.3
# 744            0.376       32.6  ...    25.7   0.743   13.0   29.7     42.7
#
#       ast  stl  blk   tov    pts
# 0    26.4  7.5  4.6  13.0  119.1
# 1    25.0  7.1  4.9  12.9  118.4
# 2    24.6  7.2  4.2  11.9  113.9
# 3    24.1  7.0  4.8  13.2  113.7
# 4    24.0  7.8  5.1  16.2  111.8
# ..    ...  ...  ...   ...    ...
# 740  18.7  8.9  5.0  17.5   91.8
# 741  19.7  7.6  4.8  13.4   91.5
# 742  20.9  7.0  4.3  13.0   92.8
# 743  20.1  7.7  4.7  17.0   93.2
# 744  21.6  7.2  4.7  16.1   96.6
#
# [745 rows x 23 columns]

# %%
All_Team_Stats_df.columns
# Out:
# Index(['team', 'season', 'wins', 'fg', 'fga', 'fg_percent', 'three_point',
#        'three_point_att', 'three_point_per', 'two_point', 'two_point_att',
#        'two_point_per', 'ft', 'ft_att', 'ft_per', 'o_reb', 'd_reb', 'tot_reb',
#        'ast', 'stl', 'blk', 'tov', 'pts'],
#       dtype='object')

# %%
All_Team_Stats_df.rename(columns={
    'fg': 'Field_Goals',
    'fga': 'Field_Goals_Attempted',
    'fg_percent': 'Field_Goal_Percentage',
    'three_point': 'Three_Pointers_Made',
    'three_point_att': 'Three_Point_Attempts',
    'three_point_per': 'Three_Point_Percentage',
    'two_point': 'Two_Pointers_Made',
    'two_point_att': 'Two_Point_Attempts',
    'two_point_per': 'Two_Point_Percentage',
    'ft': 'Free_Throws_Made',
    'ft_att': 'Free_Throw_Attempts',
    'ft_per': 'Free_Throw_Percentage',
    'o_reb': 'Offensive_Rebounds',
    'd_reb': 'Defensive_Rebounds',
    'tot_reb': 'Total_Rebounds',
    'ast': 'Assists',
    'stl': 'Steals',
    'blk': 'Blocks',
    'tov': 'Turnovers',
    'pts': 'Points'
}, inplace=True)
All_Team_Stats_df
# Out:
#     team  season  wins  Field_Goals  Field_Goals_Attempted  \
# 0    ATL    2024    35         43.2                   92.6
# 1    ATL    2023    41         44.6                   92.4
# 2    ATL    2022    43         41.5                   88.3
# 3    ATL    2021    41         40.8                   87.2
# 4    ATL    2020    20         40.6                   90.6
# ..   ...     ...   ...          ...                    ...
# 740  WAS    2004    25         33.6                   80.0
# 741  WAS    2003    37         34.3                   78.0
# 742  WAS    2002    37         35.8                   81.3
# 743  WAS    2001    19         34.5                   78.7
# 744  WAS    2000    29         36.7                   81.5
#
#      Field_Goal_Percentage  Three_Pointers_Made  Three_Point_Attempts  \
# 0                    0.467                 13.8                  37.7
# 1                    0.483                 10.8                  30.5
# 2                    0.470                 12.9                  34.4
# 3                    0.468                 12.4                  33.4
# 4                    0.449                 12.0                  36.1
# ..                     ...                  ...                   ...
# 740                  0.421                  5.3                  15.5
# 741                  0.440                  3.1                   9.9
# 742                  0.441                  3.7                   9.6
# 743                  0.439                  3.4                  10.3
# 744                  0.451                  4.1                  10.9
#
#      Three_Point_Percentage  Two_Pointers_Made  ...  Free_Throw_Attempts  \
# 0                     0.367               29.4  ...                 23.5
# 1                     0.352               33.9  ...                 22.6
# 2                     0.374               28.6  ...                 22.3
# 3                     0.373               28.4  ...                 24.2
# 4                     0.333               28.6  ...                 23.4
# ..                      ...                ...  ...                  ...
# 740                   0.341               28.4  ...                 27.0
# 741                   0.312               31.3  ...                 25.3
# 742                   0.388               32.1  ...                 22.8
# 743                   0.324               31.2  ...                 27.4
# 744                   0.376               32.6  ...                 25.7
#
#      Free_Throw_Percentage  Offensive_Rebounds  Defensive_Rebounds  \
# 0                    0.801                12.7                31.4
# 1                    0.818                11.2                33.2
# 2                    0.812                10.0                33.9
# 3                    0.812                10.6                35.1
# 4                    0.790                 9.9                33.4
# ..                     ...                 ...                 ...
# 740                  0.714                13.6                29.2
# 741                  0.779                11.2                29.2
# 742                  0.765                12.9                29.2
# 743                  0.759                12.4                28.9
# 744                  0.743                13.0                29.7
#
#      Total_Rebounds  Assists  Steals  Blocks  Turnovers  Points
# 0              44.1     26.4     7.5     4.6       13.0   119.1
# 1              44.4     25.0     7.1     4.9       12.9   118.4
# 2              44.0     24.6     7.2     4.2       11.9   113.9
# 3              45.6     24.1     7.0     4.8       13.2   113.7
# 4              43.3     24.0     7.8     5.1       16.2   111.8
# ..              ...      ...     ...     ...        ...     ...
# 740            42.8     18.7     8.9     5.0       17.5    91.8
# 741            40.4     19.7     7.6     4.8       13.4    91.5
# 742            42.0     20.9     7.0     4.3       13.0    92.8
# 743            41.3     20.1     7.7     4.7       17.0    93.2
# 744            42.7     21.6     7.2     4.7       16.1    96.6
#
# [745 rows x 23 columns]

# %%
All_Team_Stats_df.columns
# Out:
# Index(['team', 'season', 'wins', 'Field_Goals', 'Field_Goals_Attempted',
#        'Field_Goal_Percentage', 'Three_Pointers_Made', 'Three_Point_Attempts',
#        'Three_Point_Percentage', 'Two_Pointers_Made', 'Two_Point_Attempts',
#        'Two_Point_Percentage', 'Free_Throws_Made', 'Free_Throw_Attempts',
#        'Free_Throw_Percentage', 'Offensive_Rebounds', 'Defensive_Rebounds',
#        'Total_Rebounds', 'Assists', 'Steals', 'Blocks', 'Turnovers', 'Points'],
#       dtype='object')

# %%
All_Team_Stats_df['Field_Goal_Percentage'] *= 100
All_Team_Stats_df['Three_Point_Percentage'] *= 100
All_Team_Stats_df['Two_Point_Percentage'] *= 100
All_Team_Stats_df['Free_Throw_Percentage'] *= 100
All_Team_Stats_df
# Out:
#     team  season  wins  Field_Goals  Field_Goals_Attempted  \
# 0    ATL    2024    35         43.2                   92.6
# 1    ATL    2023    41         44.6                   92.4
# 2    ATL    2022    43         41.5                   88.3
# 3    ATL    2021    41         40.8                   87.2
# 4    ATL    2020    20         40.6                   90.6
# ..   ...     ...   ...          ...                    ...
# 740  WAS    2004    25         33.6                   80.0
# 741  WAS    2003    37         34.3                   78.0
# 742  WAS    2002    37         35.8                   81.3
# 743  WAS    2001    19         34.5                   78.7
# 744  WAS    2000    29         36.7                   81.5
#
#      Field_Goal_Percentage  Three_Pointers_Made  Three_Point_Attempts  \
# 0                     46.7                 13.8                  37.7
# 1                     48.3                 10.8                  30.5
# 2                     47.0                 12.9                  34.4
# 3                     46.8                 12.4                  33.4
# 4                     44.9                 12.0                  36.1
# ..                     ...                  ...                   ...
# 740                   42.1                  5.3                  15.5
# 741                   44.0                  3.1                   9.9
# 742                   44.1                  3.7                   9.6
# 743                   43.9                  3.4                  10.3
# 744                   45.1                  4.1                  10.9
#
#      Three_Point_Percentage  Two_Pointers_Made  ...  Free_Throw_Attempts  \
# 0                      36.7               29.4  ...                 23.5
# 1                      35.2               33.9  ...                 22.6
# 2                      37.4               28.6  ...                 22.3
# 3                      37.3               28.4  ...                 24.2
# 4                      33.3               28.6  ...                 23.4
# ..                      ...                ...  ...                  ...
# 740                    34.1               28.4  ...                 27.0
# 741                    31.2               31.3  ...                 25.3
# 742                    38.8               32.1  ...                 22.8
# 743                    32.4               31.2  ...                 27.4
# 744                    37.6               32.6  ...                 25.7
#
#      Free_Throw_Percentage  Offensive_Rebounds  Defensive_Rebounds  \
# 0                     80.1                12.7                31.4
# 1                     81.8                11.2                33.2
# 2                     81.2                10.0                33.9
# 3                     81.2                10.6                35.1
# 4                     79.0                 9.9                33.4
# ..                     ...                 ...                 ...
# 740                   71.4                13.6                29.2
# 741                   77.9                11.2                29.2
# 742                   76.5                12.9                29.2
# 743                   75.9                12.4                28.9
# 744                   74.3                13.0                29.7
#
#      Total_Rebounds  Assists  Steals  Blocks  Turnovers  Points
# 0              44.1     26.4     7.5     4.6       13.0   119.1
# 1              44.4     25.0     7.1     4.9       12.9   118.4
# 2              44.0     24.6     7.2     4.2       11.9   113.9
# 3              45.6     24.1     7.0     4.8       13.2   113.7
# 4              43.3     24.0     7.8     5.1       16.2   111.8
# ..              ...      ...     ...     ...        ...     ...
# 740            42.8     18.7     8.9     5.0       17.5    91.8
# 741            40.4     19.7     7.6     4.8       13.4    91.5
# 742            42.0     20.9     7.0     4.3       13.0    92.8
# 743            41.3     20.1     7.7     4.7       17.0    93.2
# 744            42.7     21.6     7.2     4.7       16.1    96.6
#
# [745 rows x 23 columns]

# %%
def plot_wins_and_stats(year, stat1, stat2):
    # Filter data for the specified year
    df = All_Team_Stats_df[All_Team_Stats_df['season'] == year].copy()
    
    # Sort the DataFrame by wins in descending order
    df = df.sort_values(by='wins', ascending=False)
    
    # Calculate average statistics for the season
    avg_stat1 = df[stat1].mean()
    avg_stat2 = df[stat2].mean()
    avg_wins = 41  # Assuming average wins to be 41
    
    # Create subplots
    fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(14, 14))
    
    # Plot Regular Season Wins as a bar chart with line to average
    for team, wins in zip(df['team'], df['wins']):
        color = 'green' if wins > avg_wins else 'red'
        ax1.bar(team, wins, color=color)
    ax1.axhline(y=avg_wins, color='red', linestyle='dotted', label='41 Wins')
    ax1.set_ylabel('Regular Season Wins', fontsize='large')
    ax1.set_title(f'Regular Season Wins for All Teams in {year}')
    ax1.legend(fontsize='large')
    
    # Plot Stat 1
    for team, value in zip(df['team'], df[stat1]):
        color = 'green' if value > avg_stat1 else 'red'
        ax2.plot(team, value, color=color, marker='d', markersize=8)
        ax2.plot([team, team], [value, avg_stat1], color='black', linestyle='-', linewidth=0.75)
    ax2.axhline(y=avg_stat1, color='red', linestyle='dotted',
                label=f'Average {stat1} ({avg_stat1:.2f})')
    ax2.set_ylabel(f'{stat1}', fontsize='large')
    ax2.set_title(f'{stat1} for All Teams in {year}')
    ax2.legend(fontsize='large')
    
    # Plot Stat 2
    for team, value in zip(df['team'], df[stat2]):
        color = 'green' if value > avg_stat2 else 'red'
        ax3.plot(team, value, color=color, marker='d', markersize=8)
        ax3.plot([team, team], [value, avg_stat2], color='black', linestyle='-', linewidth=0.75)
    ax3.axhline(y=avg_stat2, color='red', linestyle='dotted',
                label=f'Average {stat2} ({avg_stat2:.2f})')
    ax3.set_ylabel(f'{stat2}', fontsize='large')
    ax3.set_title(f'{stat2} for All Teams in {year}')
    ax3.legend(fontsize='large')
    
    # Rotate x-axis labels for better readability
    for ax in (ax1, ax2, ax3):
        ax.tick_params(axis='x', rotation=30, labelsize=15)
        ax.tick_params(axis='y', labelsize=15)
    
    plt.tight_layout()
    plt.show()

# %%
All_Team_Stats_df.columns
# Out:
# Index(['team', 'season', 'wins', 'Field_Goals', 'Field_Goals_Attempted',
#        'Field_Goal_Percentage', 'Three_Pointers_Made', 'Three_Point_Attempts',
#        'Three_Point_Percentage', 'Two_Pointers_Made', 'Two_Point_Attempts',
#        'Two_Point_Percentage', 'Free_Throws_Made', 'Free_Throw_Attempts',
#        'Free_Throw_Percentage', 'Offensive_Rebounds', 'Defensive_Rebounds',
#        'Total_Rebounds', 'Assists', 'Steals', 'Blocks', 'Turnovers', 'Points'],
#       dtype='object')

# %%
plot_wins_and_stats(2024, 'Three_Pointers_Made', 'Free_Throws_Made')

# %%
plot_wins_and_stats(2023, 'Three_Pointers_Made', 'Free_Throws_Made')

# %%
plot_wins_and_stats(2016, 'Three_Pointers_Made', 'Free_Throws_Made')

# %%
plot_wins_and_stats(2017, 'Three_Pointers_Made', 'Free_Throws_Made')
